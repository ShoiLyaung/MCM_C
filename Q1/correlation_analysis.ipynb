# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Wordle.csv')
words = df.loc[:, ["Word"]].values
words = words.reshape(len(words)).tolist()
df
# Out:
#            Date  Contest number   Word  Number of  reported results  \
# 0      2022/1/7             202  slump                        80630
# 1      2022/1/8             203  crank                       101503
# 2      2022/1/9             204  gorge                        91477
# 3     2022/1/10             205  query                       107134
# 4     2022/1/11             206  drink                       153880
# 5     2022/1/12             207  favor                       137586
# 6     2022/1/13             208  abbey                       132726
# 7     2022/1/14             209  tangy                       169484
# 8     2022/1/15             210  panic                       205880
# 9     2022/1/16             211  solar                       209609
# 10    2022/1/17             212  shire                       222197
# 11    2022/1/18             213  proxy                       220950
# 12    2022/1/19             214  point                       280622
# ...

# %%
vowels = ['a', 'e', 'i', 'o', 'u']
vowel_num = []
for word in words:
    num = 0
    for letter in word:
        if letter in vowels:
            num = num + 1
    vowel_num.append(num / 5.0)

# %%
df["Percentage of vowel in a word"] = vowel_num
df_corr = df[["Percentage of hard mode", "Percentage of frequency", "Percentage of vowel in a word"]]
df_corr
# Out:
#      Percentage of hard mode  Percentage of frequency  \
# 0                   0.016892                 0.000353
# 1                   0.017369                 0.000228
# 2                   0.020912                 0.000190
# 3                   0.020927                 0.000201
# 4                   0.019606                 0.003724
# 5                   0.022335                 0.000968
# 6                   0.025202                 0.000413
# 7                   0.023513                 0.000068
# 8                   0.022610                 0.000726
# 9                   0.023639                 0.001425
# 10                  0.025383                 0.000018
# 11                  0.028088                 0.000208
# 12                  0.025280                 0.020951
# 13                  0.027008                 0.000742
# 14                  0.027067                 0.000105
# 15                  0.028366                 0.000241
# ...

# %%
d = df_corr.corr("spearman")
sns.set_context({'figure.figsize':[7, 7]})
sns.heatmap(d, cmap="YlOrRd", linewidths=0.1, vmax=1.0, square=True, linecolor='white', annot=True)

# %%
df_1 = df[["Percentage of hard mode", "Contest number", "Number of  reported results", "Number in hard mode"]]
d = df_1.corr("spearman")
sns.set_context({'figure.figsize':[8, 8]})
sns.heatmap(d, cmap="summer", linewidths=0.1, vmax=1.0, square=True, linecolor='white', annot=True)

# %%
df_2 = df[["Percentage of hard mode", "1 try", "2 tries", "3 tries"]]
d = df_2.corr("spearman")
sns.set_context({'figure.figsize':[8, 8]})
sns.heatmap(d, cmap="summer", linewidths=0.1, vmax=1.0, square=True, linecolor='white', annot=True)

# %%
df_3 = df[["Percentage of hard mode", "4 tries", "5 tries", "6 tries", "7 or more tries (X)"]]
d = df_3.corr("spearman")
sns.set_context({'figure.figsize':[8, 8]})
sns.heatmap(d, cmap="summer", linewidths=0.1, vmax=1.0, square=True, linecolor='white', annot=True)

# %%
plt.plot(df["Contest number"], df["Percentage of hard mode"])
plt.show()
